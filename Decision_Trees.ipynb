# %%
import numpy as np
import pandas as pd
from ete3 import Tree, TreeStyle, TextFace, add_face_to_node# Just a library that helps draw trees

# %%
#opening the file that contains the data set and removing the missing values
file = open("breast-cancer.data", "r")
file_data = file.readlines()
data = []
for line in file_data:
    if '?' in line:    #Excluding the missing values in the data set
        continue
    data.append(line.strip("\n").split(','))

# %%
features = np.array(['age', 'menopause', 'tumor-size', 'inv-nodes', 'node-caps', 
        'deg-malig', 'breast', 'breast-quad', 'irradiat'])
data = np.array(data)
np.random.shuffle(data)
train_data = data[:221]
validation_data = data[221:260]
test_data = data[260:]

# %%
# Write a function which calculates the entropy of a set of data (in general we will only pass catergory labels into the function)
# HINT: look at np.unique, note unique returns in ascending order or alphabetically
def calc_entropy(data):
    # TODO: Write the function to calculate entropy. The function must return the entropy value and an array of the unique values in the data
    unique, prob = np.unique(data,return_counts=True)
    data_entropy = 0
    total = len(data)
    for i in range(0,len(prob)):
        data_entropy = data_entropy + (prob[i]/total)*np.log2(prob[i]/total)
    data_entropy =-data_entropy 
    return([data_entropy, unique]) # returns the entropy of the data as well as the set of unique value for the data

# %%
class tree_node:
    def __init__(self, data, labels, diagram_node, available_features):
        self.data = data # holds the data which the tree node will use to find the best feature
        self.labels = labels # holds the corresponding labels for each data point
        self.diagram_node = diagram_node # Used for creating the tree diagram
        self.available_features = available_features # Holds the list of names for the remaining features available at a tree node
        self.feature_index = None # Holds the index of the feature in the list of features which provides the most information gain
        self.feature_name = None # Holds the name of the feature which provides the most information gain
        self.node_values = None # Holds the unique values of the feature which provides the most information gain
        self.is_leaf = False # Reflects if the node is a leaf node
        self.class_value = None # Is set to True or False if a node classifies a data point (it is a leaf node)
        self.children = None # Array to hold the children node of this node
        self.node_entropy = calc_entropy(labels)[0] # Entropy value of the data entering the node 
                                    #(before being split by the feature which provides the most information gain)
        
        # Three cases to consider when adding a node to the tree.
        # 1. The node entropy is not 0, so the node still needs to split the data further, and there is still
        #    an unused feature to split the data with
        # 2. If the entropy is not 0 but we have already used all features to split the data
        # 3. The entropy of the data coming into the node is 0 and so the node must just pick a classification
        #    (ie: True or False)
        # It may be helpful to first complete the class functions below to see how they work
        if not (self.node_entropy == 0.0 or self.node_entropy == -0.0 or self.data.shape[1] == 0):
            # TODO: Init an empty array for self.children, then find the feature for this node to split the data,
            #       then descend the tree (add children to the current node)
            self.children = np.array([]);
            self.find_feature()
            self.descend_tree()
           
        elif self.data.shape[1] == 0:
            # TODO: Update self.is_leaf, get the unique values and their counts of the labels for this node's data,
            #       then find the index of the unique value with the largest count
            self.is_leaf = True
            unique, counts = np.unique(self.labels,return_counts=True)
            majority_class = np.argmax(counts)
            self.class_value = unique[majority_class]
            self.feature_name = str(self.class_value)
            self.diagram_node.name = self.feature_name
        else:
            self.is_leaf = True
            self.class_value = labels[0]
            self.feature_name = str(labels[0])
            self.diagram_node.name = self.feature_name

    # This function is used to calculate the information gain of each feature and pick the best feature
    def find_feature(self):
        #print("Finding feature for new node")
        feature_entropies = np.zeros(len(self.available_features ))# TODO # initialize the entropy of each feature to 0
        info_gains = np.where(feature_entropies==0,self.node_entropy,feature_entropies)# TODO # init the info gain for each feature to equal the
                                     # entropy of the data coming into the done (ie: H(D) in the formula above)
        for i in range(self.data.shape[1]): # For each feature
            print("Working on feature: ", i)
            feature_entropies[i], _ = calc_entropy(self.labels) # TODO # calculate the entropy of the data into the node
            feature_sub_classes = np.unique(self.data[:,i]) # TODO # find the unique values for the feature we are calculation info gain for
            for j in feature_sub_classes: # TODO # for each unique value of the feature
                indeces = np.where(self.data[:,i]==j) # TODO # find the data points where this feature value occurs
                sub_clas_data = []
                for ind in indeces:
                    sub_clas_data.append(self.labels[ind])
                data_ratio =len(sub_clas_data)/len(self.data[:,i]) # TODO # calc how much of the total data has this feature value
                sub_clas_entropy = calc_entropy(sub_clas_data)[0]# TODO # calc entropy for the subset of data with the feature value
                info_gains[i] -=data_ratio*sub_clas_entropy # TODO # update the information gain
            print(info_gains)
        chosen_feature = np.argmax(info_gains)                       # TODO # choose feature which gives mac info gain
        self.feature_index = chosen_feature # update features of the node class
        self.feature_name = self.available_features[self.feature_index]
        self.diagram_node.name = self.feature_name
        print("Found feature: ", self.feature_name)

    # This function is used to add nodes to the tree once the best feature to split the data is found
    def descend_tree(self):
        print("Descending tree with node entropy value: ", self.node_entropy)
        unique, counts = np.unique(self.data[:,self.feature_index],return_counts=True) # TODO # Find the unique values of the chosen feature
        self.node_values = unique # Update class values which holds the values of the feature it uses
        for i in unique: # TODO # For each unqiue value the chosen feature can take
            data_for_feature_value = np.where(self.data[:,self.feature_index]==i) # TODO # Find data where unique value for the feature occurs
            remaining_features = np.arange(self.data.shape[1])!=self.feature_index # This just drops the chosen feature from the list of unused feature names (NOTE useful for inference below)
            new_child_diagram_node = self.diagram_node.add_child(name="Temp") # used for making the tree diagram
            
            # For each unique value of the chosen feature we add a new node. Some points to note
            # First we only use the data which ass the unique value we are looking for for the feature 
            # this is found in the "data_for_feature_value" variable above
            # Secondly we remove the feature we used to split the data, the unused features are found in the 
            # variable "remaining_features"
            self.children = np.append(self.children, 
                tree_node(self.data[data_for_feature_value][:,remaining_features],self.labels[data_for_feature_value],
                new_child_diagram_node, self.available_features[remaining_features])) 

    # This function infers (predicts) the class of a new/unseen data point. We call this on the test data points
    def infer(self, data_point):
        if not self.is_leaf: # if the node we are looking at is not a leaf node (can't classify the data point)
            for i in range(self.node_values.shape[0]): # look through the set of values the node looks for
                if self.node_values[i] == data_point[self.feature_index] :   # TODO # to find which branch to descend down
                    allocated_class = self.children[i].infer(data_point[np.arange(data_point.shape[0])!= self.feature_index])  # TODO # recursively run the infer function on the child node (excluding the features which have been used already, see how this was done to get "remaining_features" when decsending the tree above)
                    return allocated_class        # return back up the tree
            print("Error found new value, can't classify")
        else:
            #print("Classified data point as: ", self.class_value)
            return(self.class_value) # If it is a leaf node then we just return the classification given by the leaf node

# %%
t = Tree() # Used for diagram, creates tree and adds root node to tree diagram (use as third input to tree_node class)
root = tree_node(train_data[:, 1:],train_data[:, 0],t,features)                # TODO # Use our class to train a decision tree on the training data
print(t.get_ascii(show_internal=True)) # prints a diagram of the decision tree
# The remainder of the window is use to draw the decsision tree. Note the last line can be removed to
# avoid rendering the image as it can look quite bad with large trees. The printed ascii version can still be seen
# in this case
ts = TreeStyle()
ts.show_leaf_name = False
def my_layout(node):
    F = TextFace(node.name, tight_text=True)
    F.rotable = True
    F.border.width = 0
    F.margin_top = 5
    F.margin_bottom = 5
    F.margin_left = 5
    F.margin_right = 5
    add_face_to_node(F, node, column=0, position="branch-right")
ts.layout_fn = my_layout
ts.mode = 'r'
ts.arc_start = 270
ts.arc_span = 185
ts.draw_guiding_lines = True
ts.scale = 100
ts.branch_vertical_margin = 100
ts.min_leaf_separation = 100
ts.show_scale = False
#t.render(file_name="%%inline", w=500, h=500, tree_style=ts)
# Out:
# Working on feature:  0
# [5.83590132 0.89049164 0.89049164 0.89049164 0.89049164 0.89049164
#  0.89049164 0.89049164 0.89049164]
# Working on feature:  1
# [5.83590132 6.69204826 0.89049164 0.89049164 0.89049164 0.89049164
#  0.89049164 0.89049164 0.89049164]
# Working on feature:  2
# [5.83590132 6.69204826 4.85086284 0.89049164 0.89049164 0.89049164
#  0.89049164 0.89049164 0.89049164]
# Working on feature:  3
# [5.83590132 6.69204826 4.85086284 6.5323115  0.89049164 0.89049164
#  0.89049164 0.89049164 0.89049164]
# Working on feature:  4
# [5.83590132 6.69204826 4.85086284 6.5323115  7.08769413 0.89049164
#  0.89049164 0.89049164 0.89049164]
# Working on feature:  5
# [5.83590132 6.69204826 4.85086284 6.5323115  7.08769413 6.35330817
#  0.89049164 0.89049164 0.89049164]
# Working on feature:  6
# [5.83590132 6.69204826 4.85086284 6.5323115  7.08769413 6.35330817
#  6.79657993 0.89049164 0.89049164]
# Working on feature:  7
# [5.83590132 6.69204826 4.85086284 6.5323115  7.08769413 6.35330817
#  6.79657993 5.81224222 0.89049164]
# Working on feature:  8
# [5.83590132 6.69204826 4.85086284 6.5323115  7.08769413 6.35330817
#  6.79657993 5.81224222 7.01959285]
# Found feature:  node-caps
# Descending tree with node entropy value:  0.8904916402194913
# Working on feature:  0
# [5.4528657  0.78244413 0.78244413 0.78244413 0.78244413 0.78244413
#  0.78244413 0.78244413]
# Working on feature:  1
# [5.4528657  6.30605833 0.78244413 0.78244413 0.78244413 0.78244413
#  0.78244413 0.78244413]
# Working on feature:  2
# [5.4528657  6.30605833 4.52235321 0.78244413 0.78244413 0.78244413
#  0.78244413 0.78244413]
# Working on feature:  3
# [5.4528657  6.30605833 4.52235321 6.79562115 0.78244413 0.78244413
#  0.78244413 0.78244413]
# Working on feature:  4
# [5.4528657  6.30605833 4.52235321 6.79562115 5.9622691  0.78244413
#  0.78244413 0.78244413]
# Working on feature:  5
# [5.4528657  6.30605833 4.52235321 6.79562115 5.9622691  6.43126578
#  0.78244413 0.78244413]
# Working on feature:  6
# [5.4528657  6.30605833 4.52235321 6.79562115 5.9622691  6.43126578
#  5.46292457 0.78244413]
# Working on feature:  7
# [5.4528657  6.30605833 4.52235321 6.79562115 5.9622691  6.43126578
#  5.46292457 6.78945519]
# Found feature:  inv-nodes
# Descending tree with node entropy value:  0.782444129406689
# Working on feature:  0
# [5.28065732 0.71663361 0.71663361 0.71663361 0.71663361 0.71663361
#  0.71663361]
# Working on feature:  1
# [5.28065732 6.13315605 0.71663361 0.71663361 0.71663361 0.71663361
#  0.71663361]
# Working on feature:  2
# [5.28065732 6.13315605 4.2913044  0.71663361 0.71663361 0.71663361
#  0.71663361]
# Working on feature:  3
# [5.28065732 6.13315605 4.2913044  5.78765998 0.71663361 0.71663361
#  0.71663361]
# Working on feature:  4
# [5.28065732 6.13315605 4.2913044  5.78765998 6.260577   0.71663361
#  0.71663361]
# Working on feature:  5
# [5.28065732 6.13315605 4.2913044  5.78765998 6.260577   5.26788572
#  0.71663361]
# Working on feature:  6
# [5.28065732 6.13315605 4.2913044  5.78765998 6.260577   5.26788572
#  6.7105587 ]
# Found feature:  irradiat
# Descending tree with node entropy value:  0.7166336117927454
# Working on feature:  0
# [5.09757262 0.65002242 0.65002242 0.65002242 0.65002242 0.65002242]
# Working on feature:  1
# [5.09757262 5.90832501 0.65002242 0.65002242 0.65002242 0.65002242]
# Working on feature:  2
# [5.09757262 5.90832501 4.16012194 0.65002242 0.65002242 0.65002242]
# Working on feature:  3
# [5.09757262 5.90832501 4.16012194 5.6095875  0.65002242 0.65002242]
# Working on feature:  4
# [5.09757262 5.90832501 4.16012194 5.6095875  6.06056292 0.65002242]
# Working on feature:  5
# [5.09757262 5.90832501 4.16012194 5.6095875  6.06056292 5.03401555]
# Found feature:  breast
# Descending tree with node entropy value:  0.6500224216483541
# Working on feature:  0
# [4.29430574 0.60143539 0.60143539 0.60143539 0.60143539]
# Working on feature:  1
# [4.29430574 5.08996754 0.60143539 0.60143539 0.60143539]
# Working on feature:  2
# [4.29430574 5.08996754 3.34494951 0.60143539 0.60143539]
# Working on feature:  3
# [4.29430574 5.08996754 3.34494951 4.7990556  0.60143539]
# Working on feature:  4
# [4.29430574 5.08996754 3.34494951 4.7990556  4.40302759]
# Found feature:  menopause
# Descending tree with node entropy value:  0.6014353864290772
# Working on feature:  0
# [3.8676053  0.30954343 0.30954343 0.30954343]
# Working on feature:  1
# [3.8676053  2.20506651 0.30954343 0.30954343]
# Working on feature:  2
# [3.8676053  2.20506651 3.70164656 0.30954343]
# Working on feature:  3
# [3.8676053  2.20506651 3.70164656 3.52550003]
# Found feature:  age
# Descending tree with node entropy value:  0.3095434291503252
# Working on feature:  0
# [1.58840732 0.30954343 0.30954343]
# Working on feature:  1
# [1.58840732 2.67783179 0.30954343]
# Working on feature:  2
# [1.58840732 2.67783179 2.4930417 ]
# Found feature:  deg-malig
# Descending tree with node entropy value:  0.3095434291503252
# Working on feature:  0
# [0.65002242 0.65002242]
# Working on feature:  1
# [0.65002242 1.44250367]
# Found feature:  breast-quad
# Descending tree with node entropy value:  0.6500224216483541
# Working on feature:  0
# [1.]
# Found feature:  tumor-size
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [1.556651   0.33729007 0.33729007]
# Working on feature:  1
# [1.556651   3.06550785 0.33729007]
# Working on feature:  2
# [1.556651   3.06550785 2.5628926 ]
# Found feature:  deg-malig
# Descending tree with node entropy value:  0.3372900666170139
# Working on feature:  0
# [3.61504748 0.81127812 0.81127812 0.81127812]
# Working on feature:  1
# [3.61504748 2.574721   0.81127812 0.81127812]
# Working on feature:  2
# [3.61504748 2.574721   3.80794906 0.81127812]
# Working on feature:  3
# [3.61504748 2.574721   3.80794906 3.410379  ]
# Found feature:  deg-malig
# Descending tree with node entropy value:  0.8112781244591328
# Working on feature:  0
# [2.33199621 0.59167278 0.59167278]
# Working on feature:  1
# [2.33199621 1.69951385 0.59167278]
# Working on feature:  2
# [2.33199621 1.69951385 2.28106453]
# Found feature:  age
# Descending tree with node entropy value:  0.5916727785823275
# Working on feature:  0
# [1.31127812 0.81127812]
# Working on feature:  1
# [1.31127812 1.31127812]
# Found feature:  tumor-size
# Descending tree with node entropy value:  0.8112781244591328
# Working on feature:  0
# [0.98335575 0.65002242]
# Working on feature:  1
# [0.98335575 1.31668909]
# Found feature:  breast-quad
# Descending tree with node entropy value:  0.6500224216483541
# Working on feature:  0
# [0.91829583]
# Found feature:  tumor-size
# Descending tree with node entropy value:  0.9182958340544896
# Working on feature:  0
# [2.64897861 0.78712659 0.78712659]
# Working on feature:  1
# [2.64897861 1.69946629 0.78712659]
# Working on feature:  2
# [2.64897861 1.69946629 2.52887014]
# Found feature:  age
# Descending tree with node entropy value:  0.7871265862012691
# Working on feature:  0
# [0.72192809 0.72192809]
# Working on feature:  1
# [0.72192809 1.12192809]
# Found feature:  breast-quad
# Descending tree with node entropy value:  0.7219280948873623
# Working on feature:  0
# [1.]
# Found feature:  tumor-size
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [1.04356444 0.54356444]
# Working on feature:  1
# [1.04356444 1.63792538]
# Found feature:  breast-quad
# Descending tree with node entropy value:  0.5435644431995964
# Working on feature:  0
# [0.81127812]
# Found feature:  tumor-size
# Descending tree with node entropy value:  0.8112781244591328
# Working on feature:  0
# [1.5 1. ]
# Working on feature:  1
# [1.5 1.5]
# Found feature:  tumor-size
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [1.5849625]
# Found feature:  breast-quad
# Descending tree with node entropy value:  0.9182958340544896
# Working on feature:  0
# [1.37095059 0.97095059 0.97095059]
# Working on feature:  1
# [1.37095059 0.97095059 0.97095059]
# Working on feature:  2
# [1.37095059 0.97095059 1.77095059]
# Found feature:  breast-quad
# Descending tree with node entropy value:  0.9709505944546686
# Working on feature:  0
# [1.5849625  0.91829583]
# Working on feature:  1
# [1.5849625  0.91829583]
# Found feature:  age
# Descending tree with node entropy value:  0.9182958340544896
# Working on feature:  0
# [3.95736658 0.707669   0.707669   0.707669   0.707669  ]
# Working on feature:  1
# [3.95736658 4.73218095 0.707669   0.707669   0.707669  ]
# Working on feature:  2
# [3.95736658 4.73218095 3.04484647 0.707669   0.707669  ]
# Working on feature:  3
# [3.95736658 4.73218095 3.04484647 4.40457648 0.707669  ]
# Working on feature:  4
# [3.95736658 4.73218095 3.04484647 4.40457648 3.75530684]
# Found feature:  menopause
# Descending tree with node entropy value:  0.7076690004167968
# Working on feature:  0
# [3.63784037 0.66319684 0.66319684 0.66319684]
# Working on feature:  1
# [3.63784037 2.38300039 0.66319684 0.66319684]
# Working on feature:  2
# [3.63784037 2.38300039 3.41403951 0.66319684]
# Working on feature:  3
# [3.63784037 2.38300039 3.41403951 3.05230762]
# Found feature:  age
# Descending tree with node entropy value:  0.6631968402398287
# Working on feature:  0
# [1.47039078 0.32275696 0.32275696]
# Working on feature:  1
# [1.47039078 2.69714096 0.32275696]
# Working on feature:  2
# [1.47039078 2.69714096 2.24799554]
# Found feature:  deg-malig
# Descending tree with node entropy value:  0.3227569588973982
# Working on feature:  0
# [0.98335575 0.65002242]
# Working on feature:  1
# [0.98335575 1.31668909]
# Found feature:  breast-quad
# Descending tree with node entropy value:  0.6500224216483541
# Working on feature:  0
# [1.5849625  0.91829583 0.91829583]
# Working on feature:  1
# [1.5849625  1.66883889 0.91829583]
# Working on feature:  2
# [1.5849625  1.66883889 2.25162917]
# Found feature:  breast-quad
# Descending tree with node entropy value:  0.9182958340544896
# Working on feature:  0
# [1.25162917 0.91829583]
# Working on feature:  1
# [1.25162917 1.25162917]
# Found feature:  tumor-size
# Descending tree with node entropy value:  0.9182958340544896
# Working on feature:  0
# [0.91829583 0.91829583]
# Working on feature:  1
# [0.91829583 0.91829583]
# Found feature:  tumor-size
# Descending tree with node entropy value:  0.9182958340544896
# Working on feature:  0
# [1.]
# Found feature:  deg-malig
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [3.40217235 0.76420451 0.76420451 0.76420451]
# Working on feature:  1
# [3.40217235 2.30160358 0.76420451 0.76420451]
# Working on feature:  2
# [3.40217235 2.30160358 3.52391148 0.76420451]
# Working on feature:  3
# [3.40217235 2.30160358 3.52391148 2.60314838]
# Found feature:  deg-malig
# Descending tree with node entropy value:  0.7642045065086203
# Working on feature:  0
# [2.05416456 0.76420451 0.76420451]
# Working on feature:  1
# [2.05416456 1.51474756 0.76420451]
# Working on feature:  2
# [2.05416456 1.51474756 1.73696978]
# Found feature:  age
# Descending tree with node entropy value:  0.7642045065086203
# Working on feature:  0
# [1. 1.]
# Working on feature:  1
# [1. 1.]
# Found feature:  tumor-size
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [1. 1.]
# Working on feature:  1
# [1. 1.]
# Found feature:  tumor-size
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [1.]
# Found feature:  breast-quad
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [2.67443004 0.69621226 0.69621226]
# Working on feature:  1
# [2.67443004 1.61839273 0.69621226]
# Working on feature:  2
# [2.67443004 1.61839273 1.99339273]
# Found feature:  age
# Descending tree with node entropy value:  0.6962122601251458
# Working on feature:  0
# [0.91829583 0.91829583]
# Working on feature:  1
# [0.91829583 0.91829583]
# Found feature:  tumor-size
# Descending tree with node entropy value:  0.9182958340544896
# Working on feature:  0
# [1.]
# Found feature:  breast-quad
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [1.43087117 0.76420451]
# Working on feature:  1
# [1.43087117 1.6530934 ]
# Found feature:  breast-quad
# Descending tree with node entropy value:  0.7642045065086203
# Working on feature:  0
# [1. 1. 1.]
# Working on feature:  1
# [1. 1. 1.]
# Working on feature:  2
# [1. 1. 1.]
# Found feature:  age
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [1. 1.]
# Working on feature:  1
# [1. 1.]
# Found feature:  tumor-size
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [1.]
# Found feature:  breast-quad
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [2.76466574 0.97095059 0.97095059 0.97095059 0.97095059 0.97095059]
# Working on feature:  1
# [2.76466574 3.40949559 0.97095059 0.97095059 0.97095059 0.97095059]
# Working on feature:  2
# [2.76466574 3.40949559 1.64643934 0.97095059 0.97095059 0.97095059]
# Working on feature:  3
# [2.76466574 3.40949559 1.64643934 2.89126919 0.97095059 0.97095059]
# Working on feature:  4
# [2.76466574 3.40949559 1.64643934 2.89126919 3.32192809 0.97095059]
# Working on feature:  5
# [2.76466574 3.40949559 1.64643934 2.89126919 3.32192809 3.02192809]
# Found feature:  menopause
# Descending tree with node entropy value:  0.9709505944546686
# Working on feature:  0
# [2.80735492 0.86312057 0.86312057 0.86312057 0.86312057]
# Working on feature:  1
# [2.80735492 1.14883485 0.86312057 0.86312057 0.86312057]
# Working on feature:  2
# [2.80735492 1.14883485 2.00597771 0.86312057 0.86312057]
# Working on feature:  3
# [2.80735492 1.14883485 2.00597771 1.8281045  0.86312057]
# Working on feature:  4
# [2.80735492 1.14883485 2.00597771 1.8281045  2.00597771]
# Found feature:  age
# Descending tree with node entropy value:  0.863120568566631
# Working on feature:  0
# [1.14883485 0.86312057 0.86312057 0.86312057]
# Working on feature:  1
# [1.14883485 2.00597771 0.86312057 0.86312057]
# Working on feature:  2
# [1.14883485 2.00597771 1.8281045  0.86312057]
# Working on feature:  3
# [1.14883485 2.00597771 1.8281045  2.00597771]
# Found feature:  deg-malig
# Descending tree with node entropy value:  0.863120568566631
# Working on feature:  0
# [1. 1. 1.]
# Working on feature:  1
# [1. 1. 1.]
# Working on feature:  2
# [1. 1. 1.]
# Found feature:  tumor-size
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [2.7083938  0.99572745 0.99572745 0.99572745 0.99572745]
# Working on feature:  1
# [2.7083938  1.66918034 0.99572745 0.99572745 0.99572745]
# Working on feature:  2
# [2.7083938  1.66918034 2.18878707 0.99572745 0.99572745]
# Working on feature:  3
# [2.7083938  1.66918034 2.18878707 2.7083938  0.99572745]
# Working on feature:  4
# [2.7083938  1.66918034 2.18878707 2.7083938  2.81185364]
# Found feature:  breast-quad
# Descending tree with node entropy value:  0.9957274520849255
# Working on feature:  0
# [2.40828578 0.99107606 0.99107606 0.99107606]
# Working on feature:  1
# [2.40828578 1.21329828 0.99107606 0.99107606]
# Working on feature:  2
# [2.40828578 1.21329828 1.65774273 0.99107606]
# Working on feature:  3
# [2.40828578 1.21329828 1.65774273 2.18606356]
# Found feature:  age
# Descending tree with node entropy value:  0.9910760598382222
# Working on feature:  0
# [0.98522814 0.98522814 0.98522814]
# Working on feature:  1
# [0.98522814 1.55665671 0.98522814]
# Working on feature:  2
# [0.98522814 1.55665671 1.84237099]
# Found feature:  breast
# Descending tree with node entropy value:  0.9852281360342515
# Working on feature:  0
# [1. 1.]
# Working on feature:  1
# [1. 1.]
# Found feature:  tumor-size
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [0.91829583 0.91829583]
# Working on feature:  1
# [0.91829583 0.91829583]
# Found feature:  tumor-size
# Descending tree with node entropy value:  0.9182958340544896
# Working on feature:  0
# [1.5 1.  1.  1. ]
# Working on feature:  1
# [1.5 1.5 1.  1. ]
# Working on feature:  2
# [1.5 1.5 1.5 1. ]
# Working on feature:  3
# [1.5 1.5 1.5 1. ]
# Found feature:  age
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [1.89629153 0.98522814 0.98522814 0.98522814 0.98522814 0.98522814
#  0.98522814]
# Working on feature:  1
# [1.89629153 3.06518638 0.98522814 0.98522814 0.98522814 0.98522814
#  0.98522814]
# Working on feature:  2
# [1.89629153 3.06518638 2.2430596  0.98522814 0.98522814 0.98522814
#  0.98522814]
# Working on feature:  3
# [1.89629153 3.06518638 2.2430596  2.72555156 0.98522814 0.98522814
#  0.98522814]
# Working on feature:  4
# [1.89629153 3.06518638 2.2430596  2.72555156 3.26196406 0.98522814
#  0.98522814]
# Working on feature:  5
# [1.89629153 3.06518638 2.2430596  2.72555156 3.26196406 2.4677201
#  0.98522814]
# Working on feature:  6
# [1.89629153 3.06518638 2.2430596  2.72555156 3.26196406 2.4677201
#  2.83339263]
# Found feature:  breast
# Descending tree with node entropy value:  0.9852281360342515
# Working on feature:  0
# [1.53948476 0.99403021 0.99403021 0.99403021 0.99403021 0.99403021]
# Working on feature:  1
# [1.53948476 2.66353275 0.99403021 0.99403021 0.99403021 0.99403021]
# Working on feature:  2
# [1.53948476 2.66353275 1.78992908 0.99403021 0.99403021 0.99403021]
# Working on feature:  3
# [1.53948476 2.66353275 1.78992908 2.33538362 0.99403021 0.99403021]
# Working on feature:  4
# [1.53948476 2.66353275 1.78992908 2.33538362 2.15356544 0.99403021]
# Working on feature:  5
# [1.53948476 2.66353275 1.78992908 2.33538362 2.15356544 2.47263589]
# Found feature:  menopause
# Descending tree with node entropy value:  0.9940302114769565
# Working on feature:  0
# [0.81127812 0.81127812 0.81127812 0.81127812 0.81127812]
# Working on feature:  1
# [0.81127812 0.81127812 0.81127812 0.81127812 0.81127812]
# Working on feature:  2
# [0.81127812 0.81127812 1.31127812 0.81127812 0.81127812]
# Working on feature:  3
# [0.81127812 0.81127812 1.31127812 0.81127812 0.81127812]
# Working on feature:  4
# [0.81127812 0.81127812 1.31127812 0.81127812 1.31127812]
# Found feature:  deg-malig
# Descending tree with node entropy value:  0.8112781244591328
# Working on feature:  0
# [1. 1. 1. 1.]
# Working on feature:  1
# [1. 1. 1. 1.]
# Working on feature:  2
# [1. 1. 1. 1.]
# Working on feature:  3
# [1. 1. 1. 1.]
# Found feature:  age
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [1. 1. 1.]
# Working on feature:  1
# [1. 1. 1.]
# Working on feature:  2
# [1. 1. 1.]
# Found feature:  tumor-size
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [1.43454914 0.86312057 0.86312057 0.86312057 0.86312057]
# Working on feature:  1
# [1.43454914 1.43454914 0.86312057 0.86312057 0.86312057]
# Working on feature:  2
# [1.43454914 1.43454914 1.54239021 0.86312057 0.86312057]
# Working on feature:  3
# [1.43454914 1.43454914 1.54239021 1.8281045  0.86312057]
# Working on feature:  4
# [1.43454914 1.43454914 1.54239021 1.8281045  1.8281045 ]
# Found feature:  breast-quad
# Descending tree with node entropy value:  0.863120568566631
# Working on feature:  0
# [1.37095059 0.97095059 0.97095059 0.97095059]
# Working on feature:  1
# [1.37095059 1.37095059 0.97095059 0.97095059]
# Working on feature:  2
# [1.37095059 1.37095059 1.37095059 0.97095059]
# Working on feature:  3
# [1.37095059 1.37095059 1.37095059 1.37095059]
# Found feature:  age
# Descending tree with node entropy value:  0.9709505944546686
# Working on feature:  0
# [1. 1. 1.]
# Working on feature:  1
# [1. 1. 1.]
# Working on feature:  2
# [1. 1. 1.]
# Found feature:  tumor-size
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [1.5849625  0.91829583 0.91829583 0.91829583 0.91829583 0.91829583
#  0.91829583]
# Working on feature:  1
# [1.5849625  1.5849625  0.91829583 0.91829583 0.91829583 0.91829583
#  0.91829583]
# Working on feature:  2
# [1.5849625  1.5849625  0.91829583 0.91829583 0.91829583 0.91829583
#  0.91829583]
# Working on feature:  3
# [1.5849625  1.5849625  0.91829583 1.5849625  0.91829583 0.91829583
#  0.91829583]
# Working on feature:  4
# [1.5849625  1.5849625  0.91829583 1.5849625  0.91829583 0.91829583
#  0.91829583]
# Working on feature:  5
# [1.5849625  1.5849625  0.91829583 1.5849625  0.91829583 0.91829583
#  0.91829583]
# Working on feature:  6
# [1.5849625  1.5849625  0.91829583 1.5849625  0.91829583 0.91829583
#  0.91829583]
# Found feature:  age
# Descending tree with node entropy value:  0.9182958340544896
# Working on feature:  0
# [3.77494664 0.98522814 0.98522814 0.98522814 0.98522814 0.98522814
#  0.98522814 0.98522814]
# Working on feature:  1
# [3.77494664 4.62385219 0.98522814 0.98522814 0.98522814 0.98522814
#  0.98522814 0.98522814]
# Working on feature:  2
# [3.77494664 4.62385219 2.95079681 0.98522814 0.98522814 0.98522814
#  0.98522814 0.98522814]
# Working on feature:  3
# [3.77494664 4.62385219 2.95079681 3.43580365 0.98522814 0.98522814
#  0.98522814 0.98522814]
# Working on feature:  4
# [3.77494664 4.62385219 2.95079681 3.43580365 4.72794273 0.98522814
#  0.98522814 0.98522814]
# Working on feature:  5
# [3.77494664 4.62385219 2.95079681 3.43580365 4.72794273 4.72888171
#  0.98522814 0.98522814]
# Working on feature:  6
# [3.77494664 4.62385219 2.95079681 3.43580365 4.72794273 4.72888171
#  3.78845766 0.98522814]
# Working on feature:  7
# [3.77494664 4.62385219 2.95079681 3.43580365 4.72794273 4.72888171
#  3.78845766 4.62385219]
# Found feature:  breast
# Descending tree with node entropy value:  0.9852281360342515
# Working on feature:  0
# [3.29064673 0.8812909  0.8812909  0.8812909  0.8812909  0.8812909
#  0.8812909 ]
# Working on feature:  1
# [3.29064673 3.91071321 0.8812909  0.8812909  0.8812909  0.8812909
#  0.8812909 ]
# Working on feature:  2
# [3.29064673 3.91071321 2.38666621 0.8812909  0.8812909  0.8812909
#  0.8812909 ]
# Working on feature:  3
# [3.29064673 3.91071321 2.38666621 2.91860475 0.8812909  0.8812909
#  0.8812909 ]
# Working on feature:  4
# [3.29064673 3.91071321 2.38666621 2.91860475 4.1233284  0.8812909
#  0.8812909 ]
# Working on feature:  5
# [3.29064673 3.91071321 2.38666621 2.91860475 4.1233284  3.35258975
#  0.8812909 ]
# Working on feature:  6
# [3.29064673 3.91071321 2.38666621 2.91860475 4.1233284  3.35258975
#  3.98859476]
# Found feature:  deg-malig
# Descending tree with node entropy value:  0.8812908992306927
# Working on feature:  0
# [2.78415913 0.97986876 0.97986876 0.97986876 0.97986876 0.97986876]
# Working on feature:  1
# [2.78415913 2.60568334 0.97986876 0.97986876 0.97986876 0.97986876]
# Working on feature:  2
# [2.78415913 2.60568334 1.87610938 0.97986876 0.97986876 0.97986876]
# Working on feature:  3
# [2.78415913 2.60568334 1.87610938 2.47986876 0.97986876 0.97986876]
# Working on feature:  4
# [2.78415913 2.60568334 1.87610938 2.47986876 2.11400546 0.97986876]
# Working on feature:  5
# [2.78415913 2.60568334 1.87610938 2.47986876 2.11400546 2.60568334]
# Found feature:  age
# Descending tree with node entropy value:  0.9798687566511528
# Working on feature:  0
# [2.13792538 0.54356444 0.54356444 0.54356444 0.54356444]
# Working on feature:  1
# [2.13792538 1.04356444 0.54356444 0.54356444 0.54356444]
# Working on feature:  2
# [2.13792538 1.04356444 1.79356444 0.54356444 0.54356444]
# Working on feature:  3
# [2.13792538 1.04356444 1.79356444 1.9947695  0.54356444]
# Working on feature:  4
# [2.13792538 1.04356444 1.79356444 1.9947695  2.13792538]
# Found feature:  menopause
# Descending tree with node entropy value:  0.5435644431995964
# Working on feature:  0
# [0.81127812 0.81127812 0.81127812 0.81127812]
# Working on feature:  1
# [0.81127812 0.81127812 0.81127812 0.81127812]
# Working on feature:  2
# [0.81127812 0.81127812 1.31127812 0.81127812]
# Working on feature:  3
# [0.81127812 0.81127812 1.31127812 1.31127812]
# Found feature:  breast-quad
# Descending tree with node entropy value:  0.8112781244591328
# Working on feature:  0
# [2.41239878 0.50325833 0.50325833 0.50325833 0.50325833 0.50325833]
# Working on feature:  1
# [2.41239878 3.28103611 0.50325833 0.50325833 0.50325833 0.50325833]
# Working on feature:  2
# [2.41239878 3.28103611 1.72548056 0.50325833 0.50325833 0.50325833]
# Working on feature:  3
# [2.41239878 3.28103611 1.72548056 2.03945192 0.50325833 0.50325833]
# Working on feature:  4
# [2.41239878 3.28103611 1.72548056 2.03945192 2.9043295  0.50325833]
# Working on feature:  5
# [2.41239878 3.28103611 1.72548056 2.03945192 2.9043295  3.37344657]
# Found feature:  irradiat
# Descending tree with node entropy value:  0.5032583347756457
# Working on feature:  0
# [1.43454914 0.86312057 0.86312057 0.86312057 0.86312057]
# Working on feature:  1
# [1.43454914 2.11381878 0.86312057 0.86312057 0.86312057]
# Working on feature:  2
# [1.43454914 2.11381878 1.43454914 0.86312057 0.86312057]
# Working on feature:  3
# [1.43454914 2.11381878 1.43454914 1.43454914 0.86312057]
# Working on feature:  4
# [1.43454914 2.11381878 1.43454914 1.43454914 2.00597771]
# Found feature:  menopause
# Descending tree with node entropy value:  0.863120568566631
# Working on feature:  0
# [1.5 1.  1.  1. ]
# Working on feature:  1
# [1.5 1.  1.  1. ]
# Working on feature:  2
# [1.5 1.  1.5 1. ]
# Working on feature:  3
# [1.5 1.  1.5 1. ]
# Found feature:  age
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [0.91829583 0.91829583 0.91829583]
# Working on feature:  1
# [0.91829583 0.91829583 0.91829583]
# Working on feature:  2
# [0.91829583 0.91829583 0.91829583]
# Found feature:  tumor-size
# Descending tree with node entropy value:  0.9182958340544896
# Working on feature:  0
# [2.58731599 0.94945202 0.94945202 0.94945202 0.94945202 0.94945202
#  0.94945202]
# Working on feature:  1
# [2.58731599 3.31107125 0.94945202 0.94945202 0.94945202 0.94945202
#  0.94945202]
# Working on feature:  2
# [2.58731599 3.31107125 1.97628228 0.94945202 0.94945202 0.94945202
#  0.94945202]
# Working on feature:  3
# [2.58731599 3.31107125 1.97628228 2.21260991 0.94945202 0.94945202
#  0.94945202]
# Working on feature:  4
# [2.58731599 3.31107125 1.97628228 2.21260991 3.26608425 0.94945202
#  0.94945202]
# Working on feature:  5
# [2.58731599 3.31107125 1.97628228 2.21260991 3.26608425 3.27255546
#  0.94945202]
# Working on feature:  6
# [2.58731599 3.31107125 1.97628228 2.21260991 3.26608425 3.27255546
#  3.31107125]
# Found feature:  menopause
# Descending tree with node entropy value:  0.9494520153879484
# Working on feature:  0
# [1.54239021 0.86312057 0.86312057 0.86312057 0.86312057 0.86312057]
# Working on feature:  1
# [1.54239021 1.14883485 0.86312057 0.86312057 0.86312057 0.86312057]
# Working on feature:  2
# [1.54239021 1.14883485 1.14883485 0.86312057 0.86312057 0.86312057]
# Working on feature:  3
# [1.54239021 1.14883485 1.14883485 1.8281045  0.86312057 0.86312057]
# Working on feature:  4
# [1.54239021 1.14883485 1.14883485 1.8281045  2.291692   0.86312057]
# Working on feature:  5
# [1.54239021 1.14883485 1.14883485 1.8281045  2.291692   2.00597771]
# Found feature:  breast-quad
# Descending tree with node entropy value:  0.863120568566631
# Working on feature:  0
# [0.91829583 0.91829583 0.91829583 0.91829583 0.91829583]
# Working on feature:  1
# [0.91829583 0.91829583 0.91829583 0.91829583 0.91829583]
# Working on feature:  2
# [0.91829583 0.91829583 0.91829583 0.91829583 0.91829583]
# Working on feature:  3
# [0.91829583 0.91829583 0.91829583 0.91829583 0.91829583]
# Working on feature:  4
# [0.91829583 0.91829583 0.91829583 0.91829583 0.91829583]
# Found feature:  age
# Descending tree with node entropy value:  0.9182958340544896
# Working on feature:  0
# [1. 1. 1. 1.]
# Working on feature:  1
# [1. 1. 1. 1.]
# Working on feature:  2
# [1. 1. 1. 1.]
# Working on feature:  3
# [1. 1. 1. 1.]
# Found feature:  tumor-size
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [1. 1. 1.]
# Working on feature:  1
# [1. 1. 1.]
# Working on feature:  2
# [1. 1. 1.]
# Found feature:  inv-nodes
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [2.37610938 0.97986876 0.97986876 0.97986876 0.97986876 0.97986876]
# Working on feature:  1
# [2.37610938 1.31320209 0.97986876 0.97986876 0.97986876 0.97986876]
# Working on feature:  2
# [2.37610938 1.31320209 1.77235001 0.97986876 0.97986876 0.97986876]
# Working on feature:  3
# [2.37610938 1.31320209 1.77235001 2.60568334 0.97986876 0.97986876]
# Working on feature:  4
# [2.37610938 1.31320209 1.77235001 2.60568334 2.67691275 0.97986876]
# Working on feature:  5
# [2.37610938 1.31320209 1.77235001 2.60568334 2.67691275 2.93901667]
# Found feature:  irradiat
# Descending tree with node entropy value:  0.9798687566511528
# Working on feature:  0
# [1.52192809 0.72192809 0.72192809 0.72192809 0.72192809]
# Working on feature:  1
# [1.52192809 1.12192809 0.72192809 0.72192809 0.72192809]
# Working on feature:  2
# [1.52192809 1.12192809 0.72192809 0.72192809 0.72192809]
# Working on feature:  3
# [1.52192809 1.12192809 0.72192809 1.6729056  0.72192809]
# Working on feature:  4
# [1.52192809 1.12192809 0.72192809 1.6729056  1.52192809]
# Found feature:  deg-malig
# Descending tree with node entropy value:  0.7219280948873623
# Working on feature:  0
# [1. 1. 1. 1.]
# Working on feature:  1
# [1. 1. 1. 1.]
# Working on feature:  2
# [1. 1. 1. 1.]
# Working on feature:  3
# [1. 1. 1. 1.]
# Found feature:  age
# Descending tree with node entropy value:  1.0
# Working on feature:  0
# [1.55665671 0.59167278 0.59167278 0.59167278 0.59167278]
# Working on feature:  1
# [1.55665671 0.87738706 0.59167278 0.59167278 0.59167278]
# Working on feature:  2
# [1.55665671 0.87738706 1.55665671 0.59167278 0.59167278]
# Working on feature:  3
# [1.55665671 0.87738706 1.55665671 1.95021206 0.59167278]
# Working on feature:  4
# [1.55665671 0.87738706 1.55665671 1.95021206 2.25019285]
# Found feature:  breast-quad
# Descending tree with node entropy value:  0.5916727785823275
#
#                                             /-no-recurrence-events
#                                            |
#                                            |         /-no-recurrence-events
#                                            |        |
#                                            |        |           /-no-recurrence-events
#                                            |        |          |
#                                            |        |-breast-quad-no-recurrence-events
#                                            |-deg-malig         |
#                                            |        |          |          /-recurrence-events
#                                            |        |           \tumor-size
#                                          /age       |                     \-no-recurrence-events
#                                         |  |        |
#                                         |  |         \-no-recurrence-events
#                                         |  |
#                                         |  |         /-no-recurrence-events
#                                         |  |        |
#                                         |  |-deg-malig-no-recurrence-events
#                                         |  |        |
#                                         |  |         \-recurrence-events
#                                         |  |
#                                         |   \-no-recurrence-events
#                                         |
#                                         |--no-recurrence-events
#                                         |
#                                         |                      /-no-recurrence-events
#                                         |                     |
#                                         |            /tumor-size-no-recurrence-events
#                                         |           |         |
#                                         |           |          \-recurrence-events
#                                 /menopause          |
#                                |        |           |                     /-no-recurrence-events
#                                |        |           |                    |
#                                |        |           |           /tumor-size-no-recurrence-events
#                                |        |         /age         |         |
#                                |        |        |  |          |          \-recurrence-events
#                                |        |        |  |-breast-quad
#                                |        |        |  |          |--no-recurrence-events
#                                |        |        |  |          |
#                                |        |        |  |           \-no-recurrence-events
#                                |        |        |  |
#                                |        |        |   \-no-recurrence-events
#                                |        |        |
#                                |        |        |              /-no-recurrence-events
#                                |        |        |             |
#                                |        |        |   /breast-quadtumor-size-no-recurrence-events
#                                |        |        |  |          |
#                                |        |        |  |           \-no-recurrence-events
#                                |        |        |  |
#                                |        |        |  |                     /-no-recurrence-events
#                                |         \deg-malig |                    |
#                                |                 |  |           /tumor-size-no-recurrence-events
#                                |                 |  |          |         |
#                                |                 |-age         |          \-no-recurrence-events
#                                |                 |  |-breast-quad
#                                |                 |  |          |--no-recurrence-events
#                                |                 |  |          |
#                                |                 |  |           \-no-recurrence-events
#                                |                 |  |
#                                |                 |  |                     /-no-recurrence-events
#                                |                 |  |          /breast-quad
#                                |                 |   \tumor-size          \-recurrence-events
#                                |                 |            |
#                                |                 |             \-no-recurrence-events
#                                |                 |
#                                |                 |              /-recurrence-events
#                           /breast                |           /age
#                          |     |                  \breast-quad  \-no-recurrence-events
#                          |     |                            |
#                          |     |                             \-recurrence-events
#                          |     |
#                          |     |            /-recurrence-events
#                          |     |           |
#                          |     |           |         /-no-recurrence-events
#                          |     |           |        |
#                          |     |           |        |           /-recurrence-events
#                          |     |           |        |          |
#                          |     |           |        |          |--no-recurrence-events
#                          |     |           |-deg-maligbreast-quad
#                          |     |           |        |          |--no-recurrence-events
#                          |     |           |        |          |
#                          |     |           |        |           \-no-recurrence-events
#                          |     |           |        |
#                          |     |           |         \-no-recurrence-events
#                          |     |           |
#                          |     |           |                     /-no-recurrence-events
#                          |     |         /age                   |
#                          |     |        |  |                    |--no-recurrence-events
#                          |     |        |  |                    |
#                          |     |        |  |           /tumor-size-recurrence-events
#                          |     |        |  |          |         |
#                          |     |        |  |          |         |--no-recurrence-events
#                          |     |        |  |-breast-quad        |
#                          |     |        |  |          |          \-recurrence-events
#                          |     |        |  |          |
#                          |     |        |  |          |          /-no-recurrence-events
#                          |     |        |  |           \tumor-size
#                          |     |        |  |                    |         /-recurrence-events
#                          |     |        |  |                     \deg-malig
#                          |     |        |  |                              \-no-recurrence-events
#                          |     |        |  |
#                          |     |        |   \-no-recurrence-events
#                          |      \menopause
#                          |              |--no-recurrence-events
#                   /irradiat             |
#                  |       |              |                      /-no-recurrence-events
#                  |       |              |            /tumor-size
#                  |       |              |           |          \-recurrence-events
#                  |       |              |         /age
#                  |       |              |        |  |--no-recurrence-events
#                  |       |              |        |  |
#                  |       |              |        |   \tumor-sizebreast-quad-no-recurrence-events
#                  |       |              |        |
#                  |       |              |        |             /breast-quad-no-recurrence-events
#                  |       |              |        |   /tumor-size
#                  |       |              |        |  |          \-no-recurrence-events
#                  |       |              |        |  |
#                  |       |              |        |  |           /-no-recurrence-events
#                  |       |               \deg-malig |          |
#                  |       |                       |  |          |--recurrence-events
#                  |       |                       |-age         |
#                  |       |                       |  |-breast-quad-no-recurrence-events
#                  |       |                       |  |          |
#                  |       |                       |  |          |--no-recurrence-events
#                  |       |                       |  |          |
#                  |       |                       |  |           \-no-recurrence-events
#                  |       |                       |  |
#                  |       |                       |   \-no-recurrence-events
#                  |       |                       |
#                  |       |                        \agetumor-sizebreast-quad-no-recurrence-events
#                  |       |
#                  |       |                     /-recurrence-events
#                  |       |                    |
#                  |       |         /agedeg-malig-no-recurrence-events
#                  |       |        |           |
#                  |       |        |           |          /-no-recurrence-events
#                  |       |        |            \tumor-size
#                  |       |        |                      \-recurrence-events
#                  |       |        |
#                  |       |        |              /-no-recurrence-events
#                  |       |        |             |
#                  |       |        |             |                /-recurrence-events
#                  |       |        |             |               |
#                  |        \menopause            |               |--recurrence-events
#                  |                |             |      /tumor-size
#                  |                |             |     |         |--no-recurrence-events
#                  |                |             |     |         |
#          /inv-nodes               |           /agebreast         \-no-recurrence-events
#         |        |                |          |  |     |
#         |        |                |          |  |     |          /-no-recurrence-events
#         |        |                |          |  |     |         |
#         |        |                |          |  |      \tumor-size-no-recurrence-events
#         |        |                |          |  |               |
#         |        |                 \breast-quad |                \-recurrence-events
#         |        |                           |  |
#         |        |                           |   \-recurrence-events
#         |        |                           |
#         |        |                           |   /-recurrence-events
#         |        |                           |  |
#         |        |                            \age-no-recurrence-events
#         |        |                              |
#         |        |                               \-recurrence-events
#         |        |
#         |        |--no-recurrence-events
#         |        |
#         |        |--no-recurrence-events
#         |        |
#         |        |      /-recurrence-events
#         |        |     |
#         |        |     |                               /-recurrence-events
#         |        |     |                  /agetumor-size
#         |        |-breast        /deg-malig            \-no-recurrence-events
#         |        |     |        |        |
#         |        |     |        |         \-recurrence-events
#         |        |     |        |
#         |        |      \menopause          /-no-recurrence-events
#         |        |              |          |
#         |        |              |          |   /-recurrence-events
#         |        |              |          |  |
#         |        |              |          |  |          /-no-recurrence-events
#         |        |               \breast-quadagetumor-size
# -node-caps       |                         |  |          \-recurrence-events
#         |        |                         |  |
#         |        |                         |   \-no-recurrence-events
#         |        |                         |
#         |        |                          \-no-recurrence-events
#         |        |
#         |        |   /-no-recurrence-events
#         |        |-age
#         |        |   \-recurrence-events
#         |        |
#         |         \-recurrence-events
#         |
#         |                  /-recurrence-events
#         |                 |
#         |                 |--recurrence-events
#         |                 |
#         |                 |                    /-no-recurrence-events
#         |                 |                   |
#         |               /age        /breast-quad-no-recurrence-events
#         |              |  |        |          |
#         |              |  |-menopause          \-recurrence-events
#         |              |  |        |
#         |              |  |         \-no-recurrence-events
#         |              |  |
#         |              |   \-recurrence-events
#         |      /deg-malig
#         |     |        |                    /-recurrence-events
#         |     |        |                   |
#         |     |        |                 /age         /-no-recurrence-events
#         |     |        |                |  |         |
#         |     |        |                |   \tumor-size-recurrence-events
#         |     |        |        /menopause           |
#         |     |        |       |        |             \-no-recurrence-events
#         |     |         \irradiat       |
#         |     |                |         \-recurrence-events
#          \breast               |
#               |                 \-recurrence-events
#               |
#               |                    /-no-recurrence-events
#               |         /breast-quad
#               |        |          |   /-recurrence-events
#               |        |           \age
#               |        |             |                   /-recurrence-events
#               |        |              \tumor-sizeinv-nodes
#               |        |                                 \-no-recurrence-events
#                \menopause
#                        |                    /-no-recurrence-events
#                        |                 /age
#                        |        /deg-malig  \-recurrence-events
#                        |       |        |
#                        |       |         \-recurrence-events
#                         \irradiat
#                                |           /-no-recurrence-events
#                                |          |
#                                 \breast-quad-no-recurrence-events
#                                           |
#                                            \-recurrence-events

# %%
count_correct = 0
for i in range(train_data.shape[0]):
    out = root.infer(train_data[i, 1:])                   # TODO # infer the class on the data point
    is_correct = (out==train_data[i, 0])          # TODO # check that the chosen class is the same as the true class label
    if is_correct:
        count_correct = count_correct + 1
print("Final Training Accuracy: ", count_correct/train_data.shape[0])
# Note test accuracy should be around 90% cause I've flipped 10% of train data labels
# Out:
# Final Training Accuracy:  0.9773755656108597

# %%
TP = 0
TN = 0
FP = 0
FN = 0
for i in range(len(test_data)):
    out = root.infer(test_data[i, 1:])
    if test_data[i, 0] == out and out=="recurrence-events":
        TP += 1
    elif test_data[i, 0] == out and out=="no-recurrence-events":
        TN += 1
    elif out=="recurrence-events":
        FP += 1
    elif out=="no-recurrence-events":
        FN
accuracy = 'accuracy is: '+str(round(((TP+TN)/(TP+TN+FP+FN))*100))+'%'
d = {'approxiamted reccurence-events': [TP,FP], 'approximated no-reccurence-events': [FN,TN]}
df = pd.DataFrame(data=d,index=['actual reccurence-events','actual no-reccurence-events'])
# Out:
# Error found new value, can't classify
# Error found new value, can't classify
# Error found new value, can't classify
# Error found new value, can't classify
# Error found new value, can't classify
# Error found new value, can't classify

# %%
accuracy
# Out:
# 'accuracy is: 80%'

# %%
df
# Out:
#                              approxiamted reccurence-events  \
# actual reccurence-events                                  0
# actual no-reccurence-events                               2
#
#                              approximated no-reccurence-events
# actual reccurence-events                                     0
# actual no-reccurence-events                                  8
